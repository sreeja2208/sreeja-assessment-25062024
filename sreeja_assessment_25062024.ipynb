# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeja2208/sreeja-assessment-25062024/blob/main/sreeja_assessment_25062024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# transforms to download model from hugging face
# save the code to github and share the link

# %%
# !pip install -q google-play-scraper
from google_play_scraper import reviews
from google_play_scraper import Sort

# %%
apps = {
    "Facebook": "com.facebook.katana",
    "WhatsApp": "com.whatsapp",
    "Facebook Messenger": "com.facebook.orca",
    "Instagram": "com.instagram.android",
    "TikTok": "com.zhiliaoapp.musically",
    "Subway Surfers": "com.kiloo.subwaysurf",
    "Facebook Lite": "com.facebook.lite",
    "Microsoft Word": 'com.microsoft.office.word',
    "Microsoft PowerPoint": "com.microsoft.office.powerpoint",
    "Snapchat": "com.snapchat.android",
    "SHAREit": "com.lenovo.anyshare.gps",
    "Netflix": "com.netflix.mediaclient",
    "Twitter": "com.twitter.android",
    "Flipboard": "flipboard.app",
    "Candy Crush Saga": "com.king.candycrushsaga",
    "Skype": "com.skype.raider",
    "Spotify": "com.spotify.music",
    "Dropbox": "com.dropbox.android",
    "Viber": "com.viber.voip",
    "LINE" : "jp.naver.line.android"

}

# %%
SORT = Sort.NEWEST
N_REVIEWS = 10000
reviews_dict =  {k : {} for k in apps}

# %%
## Scraping reviews
for app in apps.keys():
    reviews_dict[app], _  = reviews(
         apps[app],
         lang='en',
         country='us',
         sort= SORT,
         count=N_REVIEWS,
         filter_score_with=None
     )
    assert len(reviews_dict[app]) == N_REVIEWS

# %%
df = pd.DataFrame()
for app in apps.keys():
    SAVE_DIR = app  + ".csv"
    temp_df = pd.DataFrame(
        reviews_dict[app],
        columns = ["reviewId", "content", "score"]
                          )
    temp_df.to_csv(SAVE_DIR, index = False)
    temp_df["app"] = app
    df = pd.concat((df ,temp_df))
df.to_csv("all_combined.csv", index = False)
print("DONE :) ")
df.head()
# Out:
# DONE :)
#                                reviewId                      content  score  \
# 0  0a802664-98a6-4469-a651-140f3f6e32b9                 too many ads      2
# 1  dcd1c62b-8a37-4da4-900e-80c7cdf9e7de                         good      5
# 2  1f16b66b-262d-4c11-b9fc-5115e3785f6e  I want to share with others      1
# 3  2dc2759e-9637-4329-8686-7e62d546659a                    excellent      5
# 4  5aee9122-afe3-4d56-b0dc-45141ca31ba7                         nice      5
#
#         app
# 0  Facebook
# 1  Facebook
# 2  Facebook
# 3  Facebook
# 4  Facebook

# %%
df.shape
# Out:
# (200000, 4)

# %%
df['app'].unique()
# Out:
# array(['Facebook', 'WhatsApp', 'Facebook Messenger', 'Instagram',
#        'TikTok', 'Subway Surfers', 'Facebook Lite', 'Microsoft Word',
#        'Microsoft PowerPoint', 'Snapchat', 'SHAREit', 'Netflix',
#        'Twitter', 'Flipboard', 'Candy Crush Saga', 'Skype', 'Spotify',
#        'Dropbox', 'Viber', 'LINE'], dtype=object)

# %%
df['app'].value_counts()
# Out:
# app
# Facebook                10000
# WhatsApp                10000
# Viber                   10000
# Dropbox                 10000
# Spotify                 10000
# Skype                   10000
# Candy Crush Saga        10000
# Flipboard               10000
# Twitter                 10000
# Netflix                 10000
# SHAREit                 10000
# Snapchat                10000
# Microsoft PowerPoint    10000
# Microsoft Word          10000
# Facebook Lite           10000
# Subway Surfers          10000
# TikTok                  10000
# Instagram               10000
# Facebook Messenger      10000
# LINE                    10000
# Name: count, dtype: int64

# %%
df[df['app']=='Facebook']['content']
# Out:
# 0                                            too many ads
# 1                                                    good
# 2                             I want to share with others
# 3                                               excellent
# 4                                                    nice
#                               ...
# 9995                  facebook story in news feed is gone
# 9996                                                 Nice
# 9997                                              perfect
# 9998                                                 good
# 9999    Excellent this app good Facebook profile log i...
# Name: content, Length: 10000, dtype: object

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install datasets transformers huggingface_hub

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
df_facebook = df[df['app']=='Snapchat'].copy()
df_facebook.dropna(inplace=True)

# %%
df_facebook.head()
# Out:
#                                reviewId                 content  score  \
# 0  51ae3c96-d206-4523-8eb6-a0695ad16edb  6ry hay hay Boka Choda      0
# 1  164aa2fa-38b1-4bb3-a448-c4d8ffb105ac               Good apps      0
# 2  fca98a28-7134-4737-a75d-edb723399690           Much good 😊😊😊      0
# 3  edb2b4a1-566a-44eb-a489-b8e26970ce99                    good      0
# 4  5a6f31ed-0170-481b-894e-7aaa885c7f5f  MarryJaneDaleR.Velasco      0
#
#         app
# 0  Snapchat
# 1  Snapchat
# 2  Snapchat
# 3  Snapchat
# 4  Snapchat

# %%
df_facebook.shape
# Out:
# (10000, 4)

# %%
df.loc[df['score'] < 2.5, 'score'] = 0
df.loc[df['score'] >= 2.5, 'score'] = 1

# %%
df.head()
# Out:
#                                reviewId                      content  score  \
# 0  0a802664-98a6-4469-a651-140f3f6e32b9                 too many ads      0
# 1  dcd1c62b-8a37-4da4-900e-80c7cdf9e7de                         good      0
# 2  1f16b66b-262d-4c11-b9fc-5115e3785f6e  I want to share with others      0
# 3  2dc2759e-9637-4329-8686-7e62d546659a                    excellent      0
# 4  5aee9122-afe3-4d56-b0dc-45141ca31ba7                         nice      0
#
#         app
# 0  Facebook
# 1  Facebook
# 2  Facebook
# 3  Facebook
# 4  Facebook

# %%
df['score'].value_counts()
# Out:
# score
# 0    200000
# Name: count, dtype: int64

# %%
columns=['content','score']
df_facebook_processed=df_facebook[columns]
df_facebook_processed.rename(columns = {'content':'text','score':'labels'}, inplace = True)
df_facebook_processed.head()
# Out:
# <ipython-input-79-13de8190b1b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_facebook_processed.rename(columns = {'content':'text','score':'labels'}, inplace = True)
#                      text  labels
# 0  6ry hay hay Boka Choda       0
# 1               Good apps       0
# 2           Much good 😊😊😊       0
# 3                    good       0
# 4  MarryJaneDaleR.Velasco       0

# %%
df_test=df_facebook_processed[:500]
df_train=df_facebook_processed[500:3500]
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)
df_train = Dataset.from_pandas(df_train)
df_test = Dataset.from_pandas(df_test)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
def preprocess_function(text):
   return tokenizer(text, truncation=True)
df_train['text'] = df_train['text'].apply(preprocess_function)
df_test['text'] = df_test['text'].apply(preprocess_function)
# Out:
# <ipython-input-82-df1490d5c795>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['text'] = df_train['text'].apply(preprocess_function)
# <ipython-input-82-df1490d5c795>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['text'] = df_test['text'].apply(preprocess_function)

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from transformers import AutoModelForSequenceClassification
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import numpy as np
from datasets import load_metric

def compute_metrics(eval_pred):
   load_accuracy = load_metric("accuracy")
   load_f1 = load_metric("f1")

   logits, labels = eval_pred
   predictions = np.argmax(logits, axis=-1)
   accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
   f1 = load_f1.compute(predictions=predictions, references=labels)["f1"]
   return {"accuracy": accuracy, "f1": f1}

# %%
pip install accelerate -U

# %%
# !pip install transformers[torch] accelerate -U
# !pip install datasets

# %%
pip install git+https://github.com/huggingface/accelerate
# Out:
# ...
#   Cloning https://github.com/huggingface/accelerate to /tmp/pip-req-build-ah98o2im
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate /tmp/pip-req-build-ah98o2im
#   Resolved https://github.com/huggingface/accelerate to commit 1f7a79b428749f45187ec69485f2c966fe21926e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from transformers import TrainingArguments, Trainer

repo_name = "finetuning-sentiment-model-3000-samples"

training_args = TrainingArguments(
   output_dir=repo_name,
   learning_rate=2e-5,
   per_device_train_batch_size=16,
   per_device_eval_batch_size=16,
   num_train_epochs=2,
   weight_decay=0.01,
   save_strategy="epoch"
)

trainer = Trainer(
   model=model,
   train_dataset=df_train,
   eval_dataset=df_test,
   data_collator=data_collator,
   compute_metrics=compute_metrics
)

# %%
df_train
# Out:
# Dataset({
#     features: ['text', 'labels'],
#     num_rows: 3000
# })

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-3435b262f1ae> in <cell line: 1>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1883                 hf_hub_utils.enable_progress_bars()
#    1884         else:
# -> 1885             return inner_training_loop(
#    1886                 args=args,
#    1887                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2176
#    2177             step = -1
# -> 2178             for step, inputs in enumerate(epoch_iterator):
#    2179                 total_batched_samples += 1
#    2180
#
# ...

# %%
#trainer.evaluate()

# %%
from datasets import Dataset
